# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/fmichaud/PycharmProjects/medeas_simulations/three_population

# %%
simulation_subfolder = "three_population"
current_folder = os.getcwd()
home_folder = os.path.split(current_folder)[0]
simulation_subfolder = os.path.join(home_folder,simulation_subfolder)
Ls = [int(10**(i/4)) for i in range(8,25)] #regulary space with 4 point between each order of magnitude
D1 = 0.01
D2 = 0.1
all_distances1= [[0,0]]
sigma1 = [[0,0,0]]
all_distances2= [[0,0]]
sigma2 = [[0,0,0]]
for L in Ls:
    distance_summary_file = f'convergence_various_L/L_{L}.dat'
    distance_summary_file = os.path.join(simulation_subfolder,distance_summary_file)
    distances  = np.loadtxt(distance_summary_file)
    for distance in distances:
        all_distances1 = np.append(all_distances1,[[L,distance[0]]],axis = 0)
        all_distances2 = np.append(all_distances2,[[L,distance[1]]],axis = 0)
    sigma_within1 = np.std(distances[1:,0],ddof=1)
    sigma_outside1 = np.sqrt(np.sum((distances[1:,0]-2*D2)**2)/len(distances[1:,0]))
    sigma1 = np.append(sigma1,[[L,sigma_within1, sigma_outside1]],axis = 0)
    sigma_within2 = np.std(distances[1:,1],ddof=1)
    sigma_outside2 = np.sqrt(np.sum((distances[1:,1]-2*D1)**2)/len(distances[1:,1]))
    sigma2 = np.append(sigma2,[[L,sigma_within2, sigma_outside2]],axis = 0)
# Out:
# /Users/fmichaud/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: loadtxt: Empty input file: "/Users/fmichaud/PycharmProjects/medeas_simulations/three_population/convergence_various_L/L_1000.dat"
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-a58aea6111d9> in <module>()
#      17         all_distances1 = np.append(all_distances1,[[L,distance[0]]],axis = 0)
#      18         all_distances2 = np.append(all_distances2,[[L,distance[1]]],axis = 0)
# ---> 19     sigma_within1 = np.std(distances[1:,0],ddof=1)
#      20     sigma_outside1 = np.sqrt(np.sum((distances[1:,0]-2*D2)**2)/len(distances[1:,0]))
#      21     sigma1 = np.append(sigma1,[[L,sigma_within1, sigma_outside1]],axis = 0)
#
# IndexError: too many indices for array

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
plt.suptitle("Three population: extrapolation of the two split time")
plt.xlabel("Number of SNP")
plt.ylabel("Divergence time")
plt.axhline(y=0.2,c=colors[0])
plt.semilogx(all_distances1[1:,0],all_distances1[1:,1],"_")
plt.xlim((80,100000))
plt.ylim((0,0.45))
plt.axhline(y=0.02,c=colors[2])
plt.semilogx(all_distances2[1:,0],all_distances2[1:,1],"_",c=colors[2])
plt.savefig("splitting_time_three_pop.pdf")

# %%
plt.semilogx(all_distances2[1:,0],all_distances2[1:,1],"_")
plt.axhline(y=0.02,c="g")
plt.show()

# %%
all_distances1[1:]
# Out:
# array([[1.00000000e+02, 7.32863376e-01],
#        [1.00000000e+02, 8.85868079e-01],
#        [1.00000000e+02, 7.25539950e-01],
#        [1.00000000e+02, 7.03472277e-01],
#        [1.00000000e+02, 1.08769342e+00],
#        [1.00000000e+02, 8.16894099e-01],
#        [1.00000000e+02, 9.19845406e-01],
#        [1.00000000e+02, 8.00282000e-01],
#        [1.00000000e+02, 6.14585178e-01],
#        [1.00000000e+02, 9.19626446e-01],
#        [1.00000000e+02, 6.78801436e-01],
#        [1.00000000e+02, 1.13379630e+00],
#        [1.00000000e+02, 8.82567743e-01],
#        [1.00000000e+02, 8.24806931e-01],
#        [1.00000000e+02, 8.26448644e-01],
#        [1.00000000e+02, 8.87501050e-01],
#        [1.00000000e+02, 6.28215505e-01],
#        [1.00000000e+02, 9.07095574e-01],
#        [1.00000000e+02, 7.63229228e-01],
#        [1.00000000e+02, 8.80080386e-01],
#        [1.00000000e+02, 7.00079574e-01],
#        [1.00000000e+02, 7.54577792e-01],
#        [1.00000000e+02, 7.77380149e-01],
#        [1.00000000e+02, 6.56579495e-01],
#        [1.00000000e+02, 9.02219980e-01],
#        [1.00000000e+02, 7.90913139e-01],
#        [1.00000000e+02, 9.32502188e-01],
#        [1.00000000e+02, 9.54489812e-01],
#        [1.00000000e+02, 6.45780871e-01],
#        [1.00000000e+02, 8.34094871e-01],
#        [1.00000000e+02, 9.03820069e-01],
#        [1.00000000e+02, 7.99258119e-01],
#        [1.00000000e+02, 9.86753515e-01],
#        [1.00000000e+02, 8.60459129e-01],
#        [1.00000000e+02, 6.75776366e-01],
#        [1.00000000e+02, 7.89663782e-01],
#        [1.00000000e+02, 7.83183069e-01],
#        [1.00000000e+02, 8.01643307e-01],
#        [1.00000000e+02, 8.23841277e-01],
#        [1.00000000e+02, 7.62875119e-01],
#        [1.00000000e+02, 7.79113792e-01],
#        [1.00000000e+02, 1.27263642e+00],
#        [1.00000000e+02, 8.91730911e-01],
#        [1.00000000e+02, 7.87675584e-01],
#        [1.00000000e+02, 8.49430109e-01],
#        [1.00000000e+02, 1.05993164e+00],
#        [1.00000000e+02, 9.00899703e-01],
#        [1.00000000e+02, 8.40721782e-01],
#        [1.00000000e+02, 7.07510356e-01],
#        [1.00000000e+02, 7.47009545e-01],
#        [1.00000000e+02, 6.70439109e-01],
#        [1.00000000e+02, 7.53765366e-01],
#        [1.00000000e+02, 8.87937188e-01],
#        [1.00000000e+02, 8.31884000e-01],
#        [1.00000000e+02, 8.48795762e-01],
#        [1.00000000e+02, 1.01693112e+00],
#        [1.00000000e+02, 7.87800723e-01],
#        [1.00000000e+02, 1.03664459e+00],
#        [1.00000000e+02, 8.26221743e-01],
#        [1.00000000e+02, 6.99433792e-01],
#        [1.00000000e+02, 1.00074026e+00],
#        [1.00000000e+02, 6.53807446e-01],
#        [1.00000000e+02, 8.17222941e-01],
#        [1.00000000e+02, 7.86767574e-01],
#        [1.00000000e+02, 8.77937109e-01],
#        [1.00000000e+02, 8.01433109e-01],
#        [1.00000000e+02, 6.81078554e-01],
#        [1.00000000e+02, 7.72949307e-01],
#        [1.00000000e+02, 8.89931208e-01],
#        [1.00000000e+02, 8.91033950e-01],
#        [1.00000000e+02, 7.18813248e-01],
#        [1.00000000e+02, 8.54514099e-01],
#        [1.00000000e+02, 7.43581683e-01],
#        [1.00000000e+02, 7.44034000e-01],
#        [1.00000000e+02, 9.74628960e-01],
#        [1.00000000e+02, 7.40841129e-01],
#        [1.00000000e+02, 1.04076218e+00],
#        [1.00000000e+02, 8.53098673e-01],
#        [1.00000000e+02, 9.38483515e-01],
#        [1.00000000e+02, 7.20788000e-01],
#        [1.00000000e+02, 8.97474535e-01],
#        [1.00000000e+02, 8.47286614e-01],
#        [1.00000000e+02, 9.03870248e-01],
#        [1.00000000e+02, 8.48299723e-01],
#        [1.00000000e+02, 8.83802574e-01],
#        [1.00000000e+02, 8.18284970e-01],
#        [1.00000000e+02, 8.82182970e-01],
#        [1.00000000e+02, 7.06965950e-01],
#        [1.00000000e+02, 7.75998416e-01],
#        [1.00000000e+02, 8.20965693e-01],
#        [1.00000000e+02, 8.45449604e-01],
#        [1.00000000e+02, 8.42502356e-01],
#        [1.00000000e+02, 8.27559614e-01],
#        [1.00000000e+02, 7.00515267e-01],
#        [1.00000000e+02, 7.93079960e-01],
#        [1.00000000e+02, 6.50778960e-01],
#        [1.00000000e+02, 7.08945000e-01],
#        [1.00000000e+02, 9.03896693e-01],
#        [1.00000000e+02, 7.94612337e-01],
#        [1.00000000e+02, 8.92393168e-01],
#        [1.77000000e+02, 6.14335485e-01],
#        [1.77000000e+02, 5.80382960e-01],
#        [1.77000000e+02, 4.96166535e-01],
#        [1.77000000e+02, 5.10817653e-01],
#        [1.77000000e+02, 7.14944911e-01],
#        [1.77000000e+02, 4.96908752e-01],
#        [1.77000000e+02, 5.55520634e-01],
#        [1.77000000e+02, 5.27086267e-01],
#        [1.77000000e+02, 4.33188871e-01],
#        [1.77000000e+02, 4.53957644e-01],
#        [1.77000000e+02, 4.92632832e-01],
#        [1.77000000e+02, 4.94088426e-01],
#        [1.77000000e+02, 5.98217079e-01],
#        [1.77000000e+02, 6.20681495e-01],
#        [1.77000000e+02, 4.78445109e-01],
#        [1.77000000e+02, 5.29295238e-01],
#        [1.77000000e+02, 6.72567495e-01],
#        [1.77000000e+02, 4.12194782e-01],
#        [1.77000000e+02, 4.29233762e-01],
#        [1.77000000e+02, 6.23390822e-01],
#        [1.77000000e+02, 4.91048525e-01],
#        [1.77000000e+02, 7.56277178e-01],
#        [1.77000000e+02, 7.48851743e-01],
#        [1.77000000e+02, 6.00523178e-01],
#        [1.77000000e+02, 5.27159238e-01],
#        [1.77000000e+02, 6.00873663e-01],
#        [1.77000000e+02, 5.64457188e-01],
#        [1.77000000e+02, 5.99821178e-01],
#        [1.77000000e+02, 5.53455228e-01],
#        [1.77000000e+02, 4.54905188e-01],
#        [1.77000000e+02, 4.59552307e-01],
#        [1.77000000e+02, 5.34755099e-01],
#        [1.77000000e+02, 4.31095812e-01],
#        [1.77000000e+02, 4.92913218e-01],
#        [1.77000000e+02, 5.47907248e-01],
#        [1.77000000e+02, 5.44780703e-01],
#        [1.77000000e+02, 5.12409842e-01],
#        [1.77000000e+02, 5.31755416e-01],
#        [1.77000000e+02, 5.33339812e-01],
#        [1.77000000e+02, 4.59715426e-01],
#        [1.77000000e+02, 5.60719515e-01],
#        [1.77000000e+02, 5.59447614e-01],
#        [1.77000000e+02, 4.51680990e-01],
#        [1.77000000e+02, 5.01296861e-01],
#        [1.77000000e+02, 6.47006248e-01],
#        [1.77000000e+02, 5.55230416e-01],
#        [1.77000000e+02, 5.54002455e-01],
#        [1.77000000e+02, 6.05015554e-01],
#        [1.77000000e+02, 4.12687960e-01],
#        [1.77000000e+02, 5.07602703e-01],
#        [1.77000000e+02, 5.85290792e-01],
#        [1.77000000e+02, 5.52824010e-01],
#        [1.77000000e+02, 5.55357465e-01],
#        [1.77000000e+02, 5.61447386e-01],
#        [1.77000000e+02, 5.53744149e-01],
#        [1.77000000e+02, 5.71309020e-01],
#        [1.77000000e+02, 4.78696317e-01],
#        [1.77000000e+02, 5.06701228e-01],
#        [1.77000000e+02, 4.44138337e-01],
#        [1.77000000e+02, 5.57434782e-01],
#        [1.77000000e+02, 5.86759277e-01],
#        [1.77000000e+02, 5.75577733e-01],
#        [1.77000000e+02, 5.78994743e-01],
#        [1.77000000e+02, 4.95348317e-01],
#        [1.77000000e+02, 4.64018861e-01],
#        [1.77000000e+02, 4.73502891e-01],
#        [1.77000000e+02, 5.80404851e-01],
#        [1.77000000e+02, 5.40690327e-01],
#        [1.77000000e+02, 5.00400634e-01],
#        [1.77000000e+02, 5.33041980e-01],
#        [1.77000000e+02, 5.77245059e-01],
#        [1.77000000e+02, 4.81230505e-01],
#        [1.77000000e+02, 6.59548158e-01],
#        [1.77000000e+02, 5.23596604e-01],
#        [1.77000000e+02, 5.32460594e-01],
#        [1.77000000e+02, 4.84981000e-01],
#        [1.77000000e+02, 4.77094446e-01],
#        [1.77000000e+02, 6.00710733e-01],
#        [1.77000000e+02, 5.27158168e-01],
#        [1.77000000e+02, 7.58174861e-01],
#        [1.77000000e+02, 4.80279119e-01],
#        [1.77000000e+02, 5.11185158e-01],
#        [1.77000000e+02, 6.48893168e-01],
#        [1.77000000e+02, 5.42484366e-01],
#        [1.77000000e+02, 5.89754455e-01],
#        [1.77000000e+02, 5.40236564e-01],
#        [1.77000000e+02, 5.69927574e-01],
#        [1.77000000e+02, 5.36058317e-01],
#        [1.77000000e+02, 5.78984455e-01],
#        [1.77000000e+02, 5.83314277e-01],
#        [1.77000000e+02, 5.58136168e-01],
#        [1.77000000e+02, 5.24488366e-01],
#        [1.77000000e+02, 5.64667010e-01],
#        [1.77000000e+02, 4.67900812e-01],
#        [1.77000000e+02, 5.64737198e-01],
#        [1.77000000e+02, 4.94259792e-01],
#        [1.77000000e+02, 6.32460505e-01],
#        [1.77000000e+02, 5.14508861e-01],
#        [1.77000000e+02, 5.07255356e-01],
#        [1.77000000e+02, 5.71869218e-01],
#        [3.16000000e+02, 5.01309010e-01],
#        [3.16000000e+02, 4.15829980e-01],
#        [3.16000000e+02, 4.64487297e-01],
#        [3.16000000e+02, 4.92614485e-01],
#        [3.16000000e+02, 4.26569950e-01],
#        [3.16000000e+02, 5.27474238e-01],
#        [3.16000000e+02, 4.64353713e-01],
#        [3.16000000e+02, 5.58581446e-01],
#        [3.16000000e+02, 4.72952535e-01],
#        [3.16000000e+02, 4.50255614e-01],
#        [3.16000000e+02, 3.75929782e-01],
#        [3.16000000e+02, 3.98007554e-01],
#        [3.16000000e+02, 4.03866743e-01],
#        [3.16000000e+02, 4.19589099e-01],
#        [3.16000000e+02, 4.51454109e-01],
#        [3.16000000e+02, 4.60710188e-01],
#        [3.16000000e+02, 4.54932762e-01],
#        [3.16000000e+02, 4.95811228e-01],
#        [3.16000000e+02, 4.12777931e-01],
#        [3.16000000e+02, 3.93814851e-01],
#        [3.16000000e+02, 4.35537495e-01],
#        [3.16000000e+02, 4.58330059e-01],
#        [3.16000000e+02, 3.50843297e-01],
#        [3.16000000e+02, 5.02417574e-01],
#        [3.16000000e+02, 3.97418891e-01],
#        [3.16000000e+02, 3.91914881e-01],
#        [3.16000000e+02, 4.85992584e-01],
#        [3.16000000e+02, 5.52255772e-01],
#        [3.16000000e+02, 5.47041554e-01],
#        [3.16000000e+02, 3.98182564e-01],
#        [3.16000000e+02, 4.18609287e-01],
#        [3.16000000e+02, 3.88326950e-01],
#        [3.16000000e+02, 4.36016861e-01],
#        [3.16000000e+02, 4.81957238e-01],
#        [3.16000000e+02, 5.17930891e-01],
#        [3.16000000e+02, 3.89294089e-01],
#        [3.16000000e+02, 4.49788178e-01],
#        [3.16000000e+02, 4.04637931e-01],
#        [3.16000000e+02, 4.85858436e-01],
#        [3.16000000e+02, 4.48133168e-01],
#        [3.16000000e+02, 3.93169495e-01],
#        [3.16000000e+02, 4.26759842e-01],
#        [3.16000000e+02, 4.04253386e-01],
#        [3.16000000e+02, 5.62541347e-01],
#        [3.16000000e+02, 4.79612446e-01],
#        [3.16000000e+02, 5.12558277e-01],
#        [3.16000000e+02, 4.39319535e-01],
#        [3.16000000e+02, 5.08410455e-01],
#        [3.16000000e+02, 4.15315396e-01],
#        [3.16000000e+02, 3.73773396e-01],
#        [3.16000000e+02, 4.40872099e-01],
#        [3.16000000e+02, 4.22601624e-01],
#        [3.16000000e+02, 4.72831832e-01],
#        [3.16000000e+02, 4.09336485e-01],
#        [3.16000000e+02, 4.92045990e-01],
#        [3.16000000e+02, 5.10589990e-01],
#        [3.16000000e+02, 4.88725970e-01],
#        [3.16000000e+02, 4.23954604e-01],
#        [3.16000000e+02, 5.15053584e-01],
#        [3.16000000e+02, 4.62309139e-01],
#        [3.16000000e+02, 4.05179931e-01],
#        [3.16000000e+02, 3.72193624e-01],
#        [3.16000000e+02, 3.54246970e-01],
#        [3.16000000e+02, 3.93554099e-01],
#        [3.16000000e+02, 4.06182436e-01],
#        [3.16000000e+02, 4.19850525e-01],
#        [3.16000000e+02, 6.36437198e-01],
#        [3.16000000e+02, 4.97153851e-01],
#        [3.16000000e+02, 4.33698436e-01],
#        [3.16000000e+02, 5.21106782e-01],
#        [3.16000000e+02, 5.35474703e-01],
#        [3.16000000e+02, 4.38911089e-01],
#        [3.16000000e+02, 4.28546762e-01],
#        [3.16000000e+02, 4.21977376e-01],
#        [3.16000000e+02, 4.08512762e-01],
#        [3.16000000e+02, 4.46544921e-01],
#        [3.16000000e+02, 5.12168614e-01],
#        [3.16000000e+02, 4.80901901e-01],
#        [3.16000000e+02, 3.97836030e-01],
#        [3.16000000e+02, 4.17618426e-01],
#        [3.16000000e+02, 3.97308515e-01],
#        [3.16000000e+02, 4.70230980e-01],
#        [3.16000000e+02, 5.18142554e-01],
#        [3.16000000e+02, 4.38852356e-01],
#        [3.16000000e+02, 4.33535386e-01],
#        [3.16000000e+02, 4.80218139e-01],
#        [3.16000000e+02, 5.09891188e-01],
#        [3.16000000e+02, 4.96312515e-01],
#        [3.16000000e+02, 4.29990455e-01],
#        [3.16000000e+02, 4.99319881e-01],
#        [3.16000000e+02, 5.35175891e-01],
#        [3.16000000e+02, 4.49048921e-01],
#        [3.16000000e+02, 4.55014178e-01],
#        [3.16000000e+02, 4.45475713e-01],
#        [3.16000000e+02, 4.84942802e-01],
#        [3.16000000e+02, 4.41948842e-01],
#        [3.16000000e+02, 3.96021208e-01],
#        [3.16000000e+02, 4.13214921e-01],
#        [3.16000000e+02, 4.38785842e-01],
#        [3.16000000e+02, 5.14030564e-01],
#        [5.62000000e+02, 3.62798604e-01],
#        [5.62000000e+02, 4.10087802e-01],
#        [5.62000000e+02, 4.43120653e-01],
#        [5.62000000e+02, 4.07742535e-01],
#        [5.62000000e+02, 4.25563050e-01],
#        [5.62000000e+02, 4.23367891e-01],
#        [5.62000000e+02, 3.94451307e-01],
#        [5.62000000e+02, 4.34684584e-01],
#        [5.62000000e+02, 3.88118970e-01],
#        [5.62000000e+02, 4.31994703e-01],
#        [5.62000000e+02, 4.17392158e-01],
#        [5.62000000e+02, 3.57690723e-01],
#        [5.62000000e+02, 3.54089842e-01],
#        [5.62000000e+02, 4.23505287e-01],
#        [5.62000000e+02, 4.46524168e-01],
#        [5.62000000e+02, 4.09340218e-01],
#        [5.62000000e+02, 3.93468267e-01],
#        [5.62000000e+02, 4.06436455e-01],
#        [5.62000000e+02, 4.34280713e-01],
#        [5.62000000e+02, 4.23019040e-01],
#        [5.62000000e+02, 4.02861238e-01],
#        [5.62000000e+02, 4.72148663e-01],
#        [5.62000000e+02, 4.26266931e-01],
#        [5.62000000e+02, 3.40268574e-01],
#        [5.62000000e+02, 4.70126446e-01],
#        [5.62000000e+02, 4.70126446e-01],
#        [5.62000000e+02, 3.98349317e-01],
#        [5.62000000e+02, 3.44789574e-01],
#        [5.62000000e+02, 4.26605574e-01],
#        [5.62000000e+02, 4.54648644e-01],
#        [5.62000000e+02, 3.82194287e-01],
#        [5.62000000e+02, 4.61183475e-01],
#        [5.62000000e+02, 4.30250277e-01],
#        [5.62000000e+02, 4.37295802e-01],
#        [5.62000000e+02, 4.26544257e-01],
#        [5.62000000e+02, 4.44957158e-01],
#        [5.62000000e+02, 3.90207356e-01],
#        [5.62000000e+02, 4.54646386e-01],
#        [5.62000000e+02, 4.07095713e-01],
#        [5.62000000e+02, 4.37162782e-01],
#        [5.62000000e+02, 4.02256366e-01],
#        [5.62000000e+02, 3.57721168e-01],
#        [5.62000000e+02, 3.57721168e-01],
#        [5.62000000e+02, 4.32012723e-01],
#        [5.62000000e+02, 4.06402832e-01],
#        [5.62000000e+02, 4.08982287e-01],
#        [5.62000000e+02, 4.05307198e-01],
#        [5.62000000e+02, 4.00791792e-01],
#        [5.62000000e+02, 3.86462267e-01],
#        [5.62000000e+02, 4.13224505e-01],
#        [5.62000000e+02, 5.08052752e-01],
#        [5.62000000e+02, 3.95092119e-01],
#        [5.62000000e+02, 4.89169990e-01],
#        [5.62000000e+02, 3.85367911e-01],
#        [5.62000000e+02, 4.10050248e-01],
#        [5.62000000e+02, 4.37397277e-01],
#        [5.62000000e+02, 4.16032812e-01],
#        [5.62000000e+02, 4.33189743e-01],
#        [5.62000000e+02, 3.58750257e-01],
#        [5.62000000e+02, 4.55957317e-01],
#        [5.62000000e+02, 4.60752851e-01],
#        [5.62000000e+02, 3.61375436e-01],
#        [5.62000000e+02, 4.60578762e-01],
#        [5.62000000e+02, 4.20916406e-01],
#        [5.62000000e+02, 4.32392416e-01],
#        [5.62000000e+02, 4.34046376e-01],
#        [5.62000000e+02, 3.98986703e-01],
#        [5.62000000e+02, 4.13113119e-01],
#        [5.62000000e+02, 4.09103564e-01],
#        [5.62000000e+02, 3.93908356e-01],
#        [5.62000000e+02, 3.72252168e-01],
#        [5.62000000e+02, 4.15704059e-01],
#        [5.62000000e+02, 3.98296921e-01],
#        [5.62000000e+02, 4.17642545e-01],
#        [5.62000000e+02, 4.53536198e-01],
#        [5.62000000e+02, 4.16404386e-01],
#        [5.62000000e+02, 4.13630743e-01],
#        [5.62000000e+02, 4.15347752e-01],
#        [5.62000000e+02, 4.34563703e-01],
#        [5.62000000e+02, 3.43338822e-01],
#        [5.62000000e+02, 4.46099871e-01],
#        [5.62000000e+02, 4.14277851e-01],
#        [5.62000000e+02, 4.65085248e-01],
#        [5.62000000e+02, 4.47470505e-01],
#        [5.62000000e+02, 3.67569663e-01],
#        [5.62000000e+02, 4.17297475e-01],
#        [5.62000000e+02, 4.59509792e-01],
#        [5.62000000e+02, 4.36152485e-01],
#        [5.62000000e+02, 4.65462119e-01],
#        [5.62000000e+02, 3.79382782e-01],
#        [5.62000000e+02, 3.73215485e-01],
#        [5.62000000e+02, 4.54102238e-01],
#        [5.62000000e+02, 4.38832713e-01],
#        [5.62000000e+02, 4.26631238e-01],
#        [5.62000000e+02, 3.99976545e-01],
#        [5.62000000e+02, 3.69406614e-01],
#        [5.62000000e+02, 3.77268723e-01],
#        [5.62000000e+02, 4.44304634e-01],
#        [5.62000000e+02, 3.66153178e-01],
#        [5.62000000e+02, 4.40221832e-01]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.loglog(sigma1[1:,0],sigma1[1:,1],"r^",label="sigma")
ax.loglog(sigma1[1:,0],sigma1[1:,2],"^",label ="RMSD")
ax.legend()
ax.set_xlabel("L")
ax.set_ylabel("sigma(D)")
plt.savefig("RMSD_D=0.1.pdf")
fig = plt.figure()
ax = fig.add_subplot(111)
ax.loglog(sigma2[1:,0],sigma2[1:,1],"r^",label="sigma")
ax.loglog(sigma2[1:,0],sigma2[1:,2],"^",label ="RMSD")
ax.legend()
ax.set_xlabel("L")
ax.set_ylabel("sigma(D)")
plt.savefig("RMSD_D=0.1.pdf")

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')
ax.set_xlabel("Dimension 1")
ax.set_ylabel("Dimension 2")
colors_three_pop = np.concatenate((np.full(20,colors[0]),np.full(20,colors[1]),np.full(20,colors[2])))
for iL, L in enumerate([100,1000,10000,100000]):
    location_vector = os.path.join (simulation_subfolder, f'convergence_various_L/L_{L}/MDS_eigensystem/p2.vecs.data')
    val,vec = pickle.load(open(location_vector,"rb"))
    ax = fig.add_subplot(2,2,iL+1)
    ax.set_xlim([-0.3,0.3])
    if iL in [0,1]:
        ax.set_xticks([])
    if iL in [1,3]:
        ax.set_yticks([])
    ax.set_ylim([-0.3,0.3])
    ax.text(0.02,0.2,f'L = {L}')
    order = np.argsort(-val)
    dir_x = 1
    if iL == 0:
        dir_x = -1
    dir_y = 1
    if iL in [2,3]:
        dir_y = -1
    ax.scatter(dir_x*vec[:,order[0]],dir_y*vec[:,order[1]],c = colors_three_pop)
fig.show()
fig.savefig(os.path.join(simulation_subfolder,"PCA.pdf"))
# Out:
# /Users/fmichaud/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /Users/fmichaud/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
L = 10000
location_vector = os.path.join (simulation_subfolder, f'convergence_various_L/L_{L}/asd_matrices/p1.asd.data')
delta = pickle.load(open(location_vector,"rb"))
#np.fill_diagonal(delta,np.mean(delta,axis=1))
plt.imshow(delta, cmap='Blues',vmin=0.12)


start_position = (10,30,50)
label_pop = ("Pop 1", "Pop 2", "Pop 3")
plt.tick_params(bottom = False,top=True,labeltop=True,labelbottom = False)
plt.xticks(start_position,np.sort(label_pop))
plt.yticks(start_position,np.sort(label_pop))
plt.savefig(os.path.join(simulation_subfolder,"distance_matrix.pdf"))

# %%
delta
# Out:
# array([[0.    , 0.1331, 0.1275, ..., 0.1817, 0.1772, 0.1822],
#        [0.1331, 0.    , 0.1278, ..., 0.18  , 0.1745, 0.1775],
#        [0.1275, 0.1278, 0.    , ..., 0.183 , 0.1767, 0.1827],
#        ...,
#        [0.1817, 0.18  , 0.183 , ..., 0.    , 0.1265, 0.1267],
#        [0.1772, 0.1745, 0.1767, ..., 0.1265, 0.    , 0.1312],
#        [0.1822, 0.1775, 0.1827, ..., 0.1267, 0.1312, 0.    ]])
